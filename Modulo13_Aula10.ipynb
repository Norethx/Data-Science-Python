# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('co2.csv')
base.head()
base
# Out:
#    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# ..   ...          ...         ...   ...     ...
# 79   Mc3  Mississippi     chilled   250    17.9
# 80   Mc3  Mississippi     chilled   350    17.9
# 81   Mc3  Mississippi     chilled   500    17.9
# 82   Mc3  Mississippi     chilled   675    18.9
# 83   Mc3  Mississippi     chilled  1000    19.9
#
# [84 rows x 5 columns]

# %%
sbn.scatterplot(base, x = base.conc, y = base.uptake, hue = base.Type)
# Out:
# <Axes: xlabel='conc', ylabel='uptake'>

# %%
q = base.loc[base['Type'] == 'Quebec']
m = base.loc[base['Type'] == 'Mississippi']
# Out:
#    Plant         Type   Treatment  conc  uptake
# 42   Mn1  Mississippi  nonchilled    95    10.6
# 43   Mn1  Mississippi  nonchilled   175    19.2
# 44   Mn1  Mississippi  nonchilled   250    26.2
# 45   Mn1  Mississippi  nonchilled   350    30.0
# 46   Mn1  Mississippi  nonchilled   500    30.9
# 47   Mn1  Mississippi  nonchilled   675    32.4
# 48   Mn1  Mississippi  nonchilled  1000    35.5
# 49   Mn2  Mississippi  nonchilled    95    12.0
# 50   Mn2  Mississippi  nonchilled   175    22.0
# 51   Mn2  Mississippi  nonchilled   250    30.6
# 52   Mn2  Mississippi  nonchilled   350    31.8
# 53   Mn2  Mississippi  nonchilled   500    32.4
# 54   Mn2  Mississippi  nonchilled   675    31.1
# 55   Mn2  Mississippi  nonchilled  1000    31.5
# 56   Mn3  Mississippi  nonchilled    95    11.3
# 57   Mn3  Mississippi  nonchilled   175    19.4
# 58   Mn3  Mississippi  nonchilled   250    25.8
# 59   Mn3  Mississippi  nonchilled   350    27.9
# 60   Mn3  Mississippi  nonchilled   500    28.5
# ...

# %%
plt.figure()
plt.subplot(1,2,1)
sbn.scatterplot(data = q, x = q.conc, y = q.uptake)
plt.title('Quebec')
plt.subplot(1,2,2)
sbn.scatterplot(data = m, x = m.conc, y = m.uptake)
plt.title('Mississippi')
plt.tight_layout()

# %%
ch = base.loc[base['Treatment'] == 'chilled']
nc = base.loc[base['Treatment'] == 'nonchilled']

# %%
plt.figure()
plt.subplot(1,2,1)
sbn.scatterplot(ch, x = ch.conc, y = ch.uptake)
plt.title('chilled')
plt.subplot(1,2,2)
sbn.scatterplot(nc, x = nc.conc, y = nc.uptake)
plt.title('nonchilled')
plt.tight_layout()

# %%
base2 = pd.read_csv('esoph.csv')
base2.head()
# Out:
#    agegp      alcgp     tobgp  ncases  ncontrols
# 0  25-34  0-39g/day  0-9g/day       0         40
# 1  25-34  0-39g/day     10-19       0         10
# 2  25-34  0-39g/day     20-29       0          6
# 3  25-34  0-39g/day       30+       0          5
# 4  25-34      40-79  0-9g/day       0         27

# %%
sbn.catplot(x='alcgp', y='ncontrols', data=base2, jitter=False)
# Out:
# C:\Users\Ronaldo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ronaldo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sbn.catplot(x='alcgp', y='ncontrols', data=base2, col = 'tobgp')
# Out:
# C:\Users\Ronaldo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ronaldo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
